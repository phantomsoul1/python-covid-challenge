# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
#import gmaps
#from config import gkey
#import us
from pprint import pprint
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
resource_path = "../../Resources"
all_by_state_path = f"{resource_path}/AllByState.csv"
all_by_state_daily_path = f"{resource_path}/AllByState-Daily.csv"

# %%
all_by_state_df = pd.read_csv(all_by_state_path)
all_by_state_df.head()
# Out:
#    Active  Confirmed        Date  Deaths  Fatality Rate  Recovered State Name  \
# 0      12         12  2020-03-15       0         0.0000          0    Alabama
# 1    1033       1060  2020-04-01      27         0.0255          0    Alabama
# 2    3957       4075  2020-04-15     118         0.0290          0    Alabama
# 3    7005       7294  2020-05-01     289         0.0396          0    Alabama
# 4   10890      11373  2020-05-15     483         0.0425          0    Alabama
#
#   State  Land Area (mi2)  Population  Population Density  Per Capita Income  \
# 0    AL         49481.34   4846150.0            97.93894       26883.102656
# 1    AL         49481.34   4846150.0            97.93894       26883.102656
# 2    AL         49481.34   4846150.0            97.93894       26883.102656
# 3    AL         49481.34   4846150.0            97.93894       26883.102656
# 4    AL         49481.34   4846150.0            97.93894       26883.102656
#
#    Median Household Income
# 0                  41750.0
# 1                  41750.0
# 2                  41750.0
# 3                  41750.0
# 4                  41750.0

# %%
all_by_state_daily_df = pd.read_csv(all_by_state_daily_path)
all_by_state_daily_df.head()
# Out:
#    Active  Confirmed        Date  Deaths  Fatality Rate  Recovered State Name  \
# 0       0          0  2020-03-10       0            0.0          0     Alaska
# 1       0          0  2020-03-11       0            0.0          0     Alaska
# 2       0          0  2020-03-12       0            0.0          0     Alaska
# 3       1          1  2020-03-13       0            0.0          0     Alaska
# 4       1          1  2020-03-15       0            0.0          0     Alaska
#
#   State  Active Diff  Confirmed Diff  Deaths Diff  Recovered Diff      Lat  \
# 0    AK            0               0            0               0  61.3707
# 1    AK            0               0            0               0  61.3707
# 2    AK            0               0            0               0  61.3707
# 3    AK            1               1            0               0  61.3707
# 4    AK            0               0            0               0  61.3707
#
#         Lon  Land Area (mi2)  Population  Population Density  \
# 0 -152.4044        211300.81    734417.0            3.475694
# 1 -152.4044        211300.81    734417.0            3.475694
# 2 -152.4044        211300.81    734417.0            3.475694
# 3 -152.4044        211300.81    734417.0            3.475694
# 4 -152.4044        211300.81    734417.0            3.475694
#
#    Per Capita Income  Median Household Income
# 0       35617.249121                  51875.0
# 1       35617.249121                  51875.0
# 2       35617.249121                  51875.0
# 3       35617.249121                  51875.0
# 4       35617.249121                  51875.0

# %%
max_date = all_by_state_daily_df["Date"].max()
max_date
# Out:
# '2020-07-23'

# %%
max_date_df = all_by_state_daily_df.sort_values("Date", ascending = False)
max_date_df.head()
# Out:
#       Active  Confirmed        Date  Deaths  Fatality Rate  Recovered  \
# 3397    2866       2909  2020-07-23      43         0.0148          0
# 3533   23502      23818  2020-07-23     316         0.0133          0
# 3125   46617      48053  2020-07-23    1436         0.0299          0
# 2989   47120      48721  2020-07-23    1601         0.0329          0
# 2853   78036      84431  2020-07-23    6395         0.0757          0
#
#        State Name State  Active Diff  Confirmed Diff  Deaths Diff  \
# 3397      Montana    MT           96              97            1
# 3533     Nebraska    NE          327             332            5
# 3125  Mississippi    MS          969             982           13
# 2989    Minnesota    MN          751             760            9
# 2853     Michigan    MI          694             701            7
#
#       Recovered Diff      Lat       Lon  Land Area (mi2)  Population  \
# 3397               0  46.9219 -110.4544        135639.85   1038180.0
# 3533               0  41.1254  -98.2681         76243.49   1900182.0
# 3125               0  32.7416  -89.6787         45729.42   2962109.0
# 2989               0  45.6945  -93.9002         77477.43   5523621.0
# 2853               0  43.3266  -84.5361         55526.86   9935027.0
#
#       Population Density  Per Capita Income  Median Household Income
# 3397            7.653945       29784.234687                  49833.0
# 3533           24.922547       31121.371768                  55236.0
# 3125           64.774690       23556.907406                  38418.0
# 2989           71.293291       36262.683567                  60000.0
# 2853          178.922903       30369.333747                  52203.0

# %%
grouped_state_name = max_date_df.groupby(["State Name"])
grouped_state_name.first()

#
#

population_density = grouped_state_name["Population Density"].sum()
population_density

#deaths = grouped_state_name["Deaths"].sum()
#deaths

cases = grouped_state_name["Confirmed"].sum()
cases

# pop = grouped_state_name["Population"].mean()
# pop

# pop_df = pd.DataFrame({"Population": pop})
# pop_max = pop_df.sort_values("Population", ascending = False)
# pop_max.head()
# Out:
# State Name
# Alabama            2566233
# Alaska               75956
# Arizona            4631757
# Arkansas           1262582
# California        15818865
# Colorado           2679016
# Connecticut        4043870
# Delaware            905564
# Florida           10984328
# Georgia            6194208
# Hawaii               86343
# Idaho               493776
# Illinois          11209595
# Indiana            3545215
# Iowa               2034976
# Kansas             1087916
# Kentucky           1146512
# Louisiana          4958327
# Maine               241952
# Maryland           5060453
# Massachusetts      9326928
# Michigan           6156934
# Minnesota          2434711
# Mississippi        1919439
# Missouri           1662462
# Montana              89541
# Nebraska           1347492
# Nevada             1337399
# New Hampshire       445732
# New Jersey        15790214
# New Mexico          874314
# New York          38185115
# North Carolina     4121249
# North Dakota        267655
# Ohio               3940188
# Oklahoma            984725
# Oregon              627680
# Pennsylvania       7646061
# Rhode Island       1384728
# South Carolina     2333657
# South Dakota        505979
# Tennessee          3180097
# Texas             11124211
# Utah               1445905
# Vermont             115359
# Virginia           4439651
# Washington         2681993
# West Virginia       236775
# Wisconsin          2057556
# Wyoming             110557
# Name: Confirmed, dtype: int64

# %%
pop_density_df = pd.DataFrame({"Population Density": population_density,
                                "Deaths": deaths})
pop_density_vs_deaths = pop_density_df.sort_values("Population Density", ascending = False).head()
pop_density_vs_deaths
# Out:
#                Population Density   Deaths
# State Name
# New Jersey          171278.002245  1159034
# Rhode Island        139793.802278    66890
# Massachusetts       119700.720978   633470
# Connecticut         100516.552819   356838
# Maryland             85316.561086   236572

# %%
deaths_by_pop_density = pop_density_df.sort_values("Deaths", ascending = False).head()
deaths_by_pop_density
# Out:
#                Population Density   Deaths
# State Name
# New York             57684.645709  2932114
# New Jersey          171278.002245  1159034
# Massachusetts       119700.720978   633470
# Michigan             24333.514843   532839
# Illinois             31748.728552   515372

# %%
deaths_by_pop_density_df = pop_density_df.sort_values("Deaths", ascending = False)
deaths_by_pop_density_df
# Out:
#                 Population Density   Deaths
# State Name
# New York              57684.645709  2932114
# New Jersey           171278.002245  1159034
# Massachusetts        119700.720978   633470
# Michigan              24333.514843   532839
# Illinois              31748.728552   515372
# Pennsylvania          38865.423010   508743
# California            54831.991188   447574
# Connecticut          100516.552819   356838
# Louisiana             15997.920039   279122
# Florida               63874.699605   269217
# Maryland              85316.561086   236572
# Georgia               25569.707393   212299
# Ohio                  38786.387279   209735
# Indiana               25315.076116   203349
# Texas                 16977.702100   189907
# Colorado               7725.873015   135145
# Virginia              29385.677769   129750
# Washington            16994.790402   118614
# Arizona               10522.387224   114740
# Minnesota              9695.887641   100693
# North Carolina        29349.133177    96259
# Mississippi            8809.357827    75789
# Missouri              12201.029093    75300
# Alabama               13025.879049    68593
# Rhode Island         139793.802278    66890
# Wisconsin             14650.375005    59371
# South Carolina        22372.747358    56192
# Iowa                   7546.277602    49003
# Tennessee             22195.610464    44451
# Kentucky              15696.011442    44078
# Nevada                 8610.954137    42349
# Delaware              65966.959499    35223
# New Mexico             3219.277039    34849
# Oklahoma               7897.177039    33325
# New Hampshire         20122.952586    24556
# Kansas                 4932.846183    22367
# Nebraska               3389.466458    17908
# Arkansas               8165.992265    17533
# Oregon                 9085.404086    16955
# Utah                  11633.230298    12462
# Maine                  7473.259972     8625
# Idaho                  3962.091668     8404
# West Virginia         10906.200901     7261
# South Dakota           1578.456733     6263
# North Dakota           1530.886408     5823
# Vermont                9129.381095     5676
# Montana                1040.936568     2079
# Hawaii                35550.863955     1792
# Wyoming                1184.551096     1439
# Alaska                  469.218717     1287

# %%
pop_density_vs_deaths.plot(kind = "bar", alpha = 0.65, color = ("r", "g"), align = "center", figsize = (7, 5), legend = True)
plt.title("Population Density compared to Deaths", fontsize= 14, fontweight = "bold")
plt.xlabel("States")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.savefig("Population Density compared to Deaths.png")
plt.show()

# %%
deaths_by_pop_density.plot(kind = "bar", alpha = 0.65, color = ("r", "g"), align = "center", figsize = (7, 5), legend = True)
plt.title("Deaths compared to Population Density", fontsize= 14, fontweight = "bold")
plt.xlabel("States")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.savefig("Deaths compared to Population Density.png")
plt.show()

# %%
max_date_df

avg_pop = max_date_df.groupby(["State Name"])["Population"].mean()
avg_death = max_date_df.groupby(["State Name"])["Deaths"].mean()

plt.scatter(avg_pop, avg_death, marker = "o", facecolors = "red", edgecolors = "black")
plt.title("Average Population vs. Average Deaths", fontsize = 16, fontweight = "bold", color = "r")
plt.xlabel("Population (1.0 x 10^7)")
plt.ylabel("Avg. Deaths")
plt.grid()
plt.show()

# %%
avg_pop_den= max_date_df.groupby(["State Name"])["Population Density"].mean()
avg_death = max_date_df.groupby(["State Name"])["Deaths"].mean()

plt.scatter(avg_pop_den, avg_death, marker = "o", facecolors = "red", edgecolors = "black")
plt.title("Average Population Density vs. Average Deaths", fontsize = 16, fontweight = "bold", color = "r")
plt.xlabel("Population Density")
plt.ylabel("Avg. Deaths")
plt.grid()
plt.show()

# %%
correlation = st.pearsonr(avg_pop_den, avg_death)
print(correlation)
corr = (f"The correlation between both is {round(correlation[0], 2)}")
# Out:
# (0.4355213485119, 0.0015715222136753117)

# %%
x_values = avg_pop_den
y_values = avg_death
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x +" + str(round(intercept, 2))
plt.scatter(x_values, y_values, marker = "o", facecolors = "red", edgecolors = "black")
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (200, 10000), fontsize = 15, color = "red")
plt.annotate(corr, (200, 7000), fontsize = 13, color = "blue")
plt.grid()
plt.title("Avg. Deaths vs. Avg. Population Density", fontsize = 14, fontweight = "bold")
plt.xlabel("Avg. Population Density")
plt.ylabel("Avg. Deaths")
print(f"The r-squared value is: {rvalue**2}")
plt.tight_layout()
plt.savefig("Avg. Population Density vs. Avg. Deaths per State.png")
plt.show()
# Out:
# The r-squared value is: 0.1896788450096239

# %%
x_values = avg_pop_den
y_values = avg_death
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x +" + str(round(intercept, 2))
plt.scatter(x_values, y_values, marker = "o", facecolors = "red", edgecolors = "black")
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (200, 10000), fontsize = 15, color = "red")
plt.annotate(corr, (200, 7000), fontsize = 13, color = "blue")
plt.grid()
plt.title("Avg. Deaths vs. Avg. Population Density", fontsize = 14, fontweight = "bold")
plt.xlabel("Avg. Population Density")
plt.ylabel("Avg. Deaths")
print(f"The r-squared value is: {rvalue**2}")
plt.tight_layout()
plt.savefig("Avg. Population Density vs. Avg. Deaths per State.png")
plt.show()
# Out:
# The r-squared value is: 0.1896788450096239
