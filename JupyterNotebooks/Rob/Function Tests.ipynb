# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from scipy.stats import linregress
import scipy.stats as st

from ipynb.fs.full.Deaths_Median_Income_Scatter import DeathsMedInScatter
DeathsMedInScatter()

# %%
from ipynb.fs.full.Deaths_Per_Cap_Scatter import DeathsPerCapScatter
DeathsPerCapScatter()

# %%
from ipynb.fs.full.top_5_per_cap_deaths import Top5PerCapDeathsPlot
Top5PerCapDeathsPlot()
