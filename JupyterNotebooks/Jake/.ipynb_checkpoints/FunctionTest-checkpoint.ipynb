# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from scipy.stats import linregress
import scipy.stats as st

from ipynb.fs.full.PopDensityDeathsBar import PopDensityDeaths
PopDensityDeaths()

# %%
from ipynb.fs.full.DeathsPopDensityBar import DeathsPopDensity
DeathsPopDensity()

# %%
from ipynb.fs.full.PopDensityDeathsScatter import PopDensityDeathsScatter
PopDensityDeathsScatter()

# %%
from ipynb.fs.full.DeathsPopDensityLine import DeathsPopDensityLine
DeathsPopDensityLine()

# %%
from ipynb.fs.full.PopDensityDeathsLine import PopDensityDeathsLine
PopDensityDeathsLine()
