# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import us

from datetime import date, timedelta
from pprint import pprint

# %%
#Initialize data source URL
url = 'https://covid-api.com/api/reports'

#Initialize list of dates: all dates between today and March 1, 2020
#API requires queries by date, so we will need to request one date at a time
start_date = date(2020,3,1)
end_date = date.today()

#Uncomment this assignment to run the original 'bi-monthly' data frame
dates = ['2020-03-01', '2020-03-15', '2020-04-01', '2020-04-15', '2020-05-01',
         '2020-05-15', '2020-06-01', '2020-06-15', '2020-07-01', '2020-07-15']

#Uncomment this assignment to run the enhanced 'daily' data frame
#dates = [str(start_date + timedelta(n)) for n in range(int((end_date - start_date).days))]

#Initialize data frame
cases_df = pd.DataFrame(columns=[
    'Active',
    'Confirmed',
    'Date', 
    'Deaths',
    'Fatality Rate', 
    'Recovered', 
    'State',
    'State Abbr',
    'Active Diff',
    'Confirmed Diff',
    'Deaths Diff',
    'Recovered Diff',
    'Lat',
    'Lon'
])

cases_df.head()
# Out:
# Empty DataFrame
# Columns: [Active, Confirmed, Date, Deaths, Fatality Rate, Recovered, State, State Abbr, Active Diff, Confirmed Diff, Deaths Diff, Recovered Diff, Lat, Lon]
# Index: []

# %%
query_params = {'date' : '2020-07-22',
                'iso' : 'USA'}
response = requests.get(url, params=query_params)
json = response.json()
pprint(json)
# Out:
# {'data': [{'active': 70449,
#            'active_diff': 1394,
#            'confirmed': 71813,
#            'confirmed_diff': 1455,
#            'date': '2020-07-22',
#            'deaths': 1364,
#            'deaths_diff': 61,
#            'fatality_rate': 0.019,
#            'last_update': '2020-07-23 05:15:04',
#            'recovered': 0,
#            'recovered_diff': 0,
#            'region': {'cities': [{'confirmed': 863,
#                                   'confirmed_diff': 18,
#                                   'date': '2020-07-22',
#                                   'deaths': 20,
#                                   'deaths_diff': 0,
#                                   'fips': 1001,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.53952745',
#                                   'long': '-86.64408227',
#                                   'name': 'Autauga'},
#                                  {'confirmed': 2164,
#                                   'confirmed_diff': 87,
#                                   'date': '2020-07-22',
#                                   'deaths': 15,
#                                   'deaths_diff': 0,
#                                   'fips': 1003,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '30.72774991',
#                                   'long': '-87.72207058',
#                                   'name': 'Baldwin'},
#                                  {'confirmed': 487,
#                                   'confirmed_diff': 3,
#                                   'date': '2020-07-22',
#                                   'deaths': 4,
#                                   'deaths_diff': 0,
#                                   'fips': 1005,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.868263',
#                                   'long': '-85.3871286',
#                                   'name': 'Barbour'},
#                                  {'confirmed': 282,
#                                   'confirmed_diff': 4,
#                                   'date': '2020-07-22',
#                                   'deaths': 2,
#                                   'deaths_diff': 0,
#                                   'fips': 1007,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.99642064',
#                                   'long': '-87.12511459999996',
#                                   'name': 'Bibb'},
#                                  {'confirmed': 498,
#                                   'confirmed_diff': 19,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 0,
#                                   'fips': 1009,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.98210918',
#                                   'long': '-86.56790593',
#                                   'name': 'Blount'},
#                                  {'confirmed': 402,
#                                   'confirmed_diff': 6,
#                                   'date': '2020-07-22',
#                                   'deaths': 11,
#                                   'deaths_diff': 1,
#                                   'fips': 1011,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.10030533',
#                                   'long': '-85.71265535',
#                                   'name': 'Bullock'},
#                                  {'confirmed': 693,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 33,
#                                   'deaths_diff': 0,
#                                   'fips': 1013,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.75300095',
#                                   'long': '-86.68057478',
#                                   'name': 'Butler'},
#                                  {'confirmed': 870,
#                                   'confirmed_diff': 21,
#                                   'date': '2020-07-22',
#                                   'deaths': 6,
#                                   'deaths_diff': 0,
#                                   'fips': 1015,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.77483727',
#                                   'long': '-85.82630386',
#                                   'name': 'Calhoun'},
#                                  {'confirmed': 748,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 34,
#                                   'deaths_diff': 1,
#                                   'fips': 1017,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.91360079',
#                                   'long': '-85.39072749',
#                                   'name': 'Chambers'},
#                                  {'confirmed': 174,
#                                   'confirmed_diff': 2,
#                                   'date': '2020-07-22',
#                                   'deaths': 7,
#                                   'deaths_diff': 0,
#                                   'fips': 1019,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.17805983',
#                                   'long': '-85.60638968',
#                                   'name': 'Cherokee'},
#                                  {'confirmed': 507,
#                                   'confirmed_diff': 16,
#                                   'date': '2020-07-22',
#                                   'deaths': 4,
#                                   'deaths_diff': 1,
#                                   'fips': 1021,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.85044126',
#                                   'long': '-86.7173256',
#                                   'name': 'Chilton'},
#                                  {'confirmed': 244,
#                                   'confirmed_diff': 6,
#                                   'date': '2020-07-22',
#                                   'deaths': 12,
#                                   'deaths_diff': 0,
#                                   'fips': 1023,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.02227341',
#                                   'long': '-88.26564429999998',
#                                   'name': 'Choctaw'},
#                                  {'confirmed': 403,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 8,
#                                   'deaths_diff': 1,
#                                   'fips': 1025,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.68099859',
#                                   'long': '-87.83548597',
#                                   'name': 'Clarke'},
#                                  {'confirmed': 135,
#                                   'confirmed_diff': 3,
#                                   'date': '2020-07-22',
#                                   'deaths': 2,
#                                   'deaths_diff': 0,
#                                   'fips': 1027,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.26984193',
#                                   'long': '-85.85836077',
#                                   'name': 'Clay'},
#                                  {'confirmed': 82,
#                                   'confirmed_diff': 2,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 0,
#                                   'fips': 1029,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.67679204',
#                                   'long': '-85.52005899',
#                                   'name': 'Cleburne'},
#                                  {'confirmed': 555,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 4,
#                                   'deaths_diff': 0,
#                                   'fips': 1031,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.39932826',
#                                   'long': '-85.98901039',
#                                   'name': 'Coffee'},
#                                  {'confirmed': 805,
#                                   'confirmed_diff': 20,
#                                   'date': '2020-07-22',
#                                   'deaths': 10,
#                                   'deaths_diff': 1,
#                                   'fips': 1033,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.69847452',
#                                   'long': '-87.80168544',
#                                   'name': 'Colbert'},
#                                  {'confirmed': 299,
#                                   'confirmed_diff': 2,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 0,
#                                   'fips': 1035,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.43401703',
#                                   'long': '-86.99320044',
#                                   'name': 'Conecuh'},
#                                  {'confirmed': 74,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 0,
#                                   'fips': 1037,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.93690146',
#                                   'long': '-86.24847739',
#                                   'name': 'Coosa'},
#                                  {'confirmed': 577,
#                                   'confirmed_diff': 8,
#                                   'date': '2020-07-22',
#                                   'deaths': 17,
#                                   'deaths_diff': 1,
#                                   'fips': 1039,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.2477854',
#                                   'long': '-86.45050893',
#                                   'name': 'Covington'},
#                                  {'confirmed': 205,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 3,
#                                   'deaths_diff': 0,
#                                   'fips': 1041,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.72941803',
#                                   'long': '-86.31593104',
#                                   'name': 'Crenshaw'},
#                                  {'confirmed': 859,
#                                   'confirmed_diff': 20,
#                                   'date': '2020-07-22',
#                                   'deaths': 7,
#                                   'deaths_diff': 0,
#                                   'fips': 1043,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.13020303',
#                                   'long': '-86.86888037',
#                                   'name': 'Cullman'},
#                                  {'confirmed': 568,
#                                   'confirmed_diff': 11,
#                                   'date': '2020-07-22',
#                                   'deaths': 8,
#                                   'deaths_diff': 4,
#                                   'fips': 1045,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.43037123',
#                                   'long': '-85.61095742',
#                                   'name': 'Dale'},
#                                  {'confirmed': 1158,
#                                   'confirmed_diff': 8,
#                                   'date': '2020-07-22',
#                                   'deaths': 16,
#                                   'deaths_diff': 3,
#                                   'fips': 1047,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.32688101',
#                                   'long': '-87.10866709999998',
#                                   'name': 'Dallas'},
#                                  {'confirmed': 1361,
#                                   'confirmed_diff': 19,
#                                   'date': '2020-07-22',
#                                   'deaths': 8,
#                                   'deaths_diff': 0,
#                                   'fips': 1049,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.45946862',
#                                   'long': '-85.80782906',
#                                   'name': 'DeKalb'},
#                                  {'confirmed': 1313,
#                                   'confirmed_diff': 23,
#                                   'date': '2020-07-22',
#                                   'deaths': 33,
#                                   'deaths_diff': 6,
#                                   'fips': 1051,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.59785413',
#                                   'long': '-86.14415284',
#                                   'name': 'Elmore'},
#                                  {'confirmed': 697,
#                                   'confirmed_diff': 21,
#                                   'date': '2020-07-22',
#                                   'deaths': 15,
#                                   'deaths_diff': 2,
#                                   'fips': 1053,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.1256789',
#                                   'long': '-87.15918694',
#                                   'name': 'Escambia'},
#                                  {'confirmed': 1440,
#                                   'confirmed_diff': 18,
#                                   'date': '2020-07-22',
#                                   'deaths': 15,
#                                   'deaths_diff': 0,
#                                   'fips': 1055,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.04567266',
#                                   'long': '-86.04051873',
#                                   'name': 'Etowah'},
#                                  {'confirmed': 124,
#                                   'confirmed_diff': 2,
#                                   'date': '2020-07-22',
#                                   'deaths': 5,
#                                   'deaths_diff': 0,
#                                   'fips': 1057,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.72076938',
#                                   'long': '-87.73886638',
#                                   'name': 'Fayette'},
#                                  {'confirmed': 1044,
#                                   'confirmed_diff': 6,
#                                   'date': '2020-07-22',
#                                   'deaths': 17,
#                                   'deaths_diff': 1,
#                                   'fips': 1059,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.44235334',
#                                   'long': '-87.84289505',
#                                   'name': 'Franklin'},
#                                  {'confirmed': 158,
#                                   'confirmed_diff': 8,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 1061,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.09389027',
#                                   'long': '-85.83572839',
#                                   'name': 'Geneva'},
#                                  {'confirmed': 225,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 10,
#                                   'deaths_diff': 1,
#                                   'fips': 1063,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.85504247',
#                                   'long': '-87.95684022',
#                                   'name': 'Greene'},
#                                  {'confirmed': 403,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 22,
#                                   'deaths_diff': 0,
#                                   'fips': 1065,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.76039258',
#                                   'long': '-87.63284988',
#                                   'name': 'Hale'},
#                                  {'confirmed': 198,
#                                   'confirmed_diff': 4,
#                                   'date': '2020-07-22',
#                                   'deaths': 3,
#                                   'deaths_diff': 0,
#                                   'fips': 1067,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.51148016',
#                                   'long': '-85.24267944',
#                                   'name': 'Henry'},
#                                  {'confirmed': 950,
#                                   'confirmed_diff': 25,
#                                   'date': '2020-07-22',
#                                   'deaths': 8,
#                                   'deaths_diff': 0,
#                                   'fips': 1069,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.15197924',
#                                   'long': '-85.29939599',
#                                   'name': 'Houston'},
#                                  {'confirmed': 597,
#                                   'confirmed_diff': 15,
#                                   'date': '2020-07-22',
#                                   'deaths': 3,
#                                   'deaths_diff': 0,
#                                   'fips': 1071,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.78144169',
#                                   'long': '-85.99750489',
#                                   'name': 'Jackson'},
#                                  {'confirmed': 9275,
#                                   'confirmed_diff': 187,
#                                   'date': '2020-07-22',
#                                   'deaths': 190,
#                                   'deaths_diff': 2,
#                                   'fips': 1073,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.55554728',
#                                   'long': '-86.89506300000002',
#                                   'name': 'Jefferson'},
#                                  {'confirmed': 145,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 0,
#                                   'fips': 1075,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.77995024',
#                                   'long': '-88.09668032',
#                                   'name': 'Lamar'},
#                                  {'confirmed': 815,
#                                   'confirmed_diff': 17,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 1,
#                                   'fips': 1077,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.90171875',
#                                   'long': '-87.65624729',
#                                   'name': 'Lauderdale'},
#                                  {'confirmed': 210,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 1079,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.52041498',
#                                   'long': '-87.31069453',
#                                   'name': 'Lawrence'},
#                                  {'confirmed': 2117,
#                                   'confirmed_diff': 29,
#                                   'date': '2020-07-22',
#                                   'deaths': 38,
#                                   'deaths_diff': 0,
#                                   'fips': 1081,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.60154883',
#                                   'long': '-85.35132246',
#                                   'name': 'Lee'},
#                                  {'confirmed': 930,
#                                   'confirmed_diff': 26,
#                                   'date': '2020-07-22',
#                                   'deaths': 7,
#                                   'deaths_diff': 1,
#                                   'fips': 1083,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.81185586',
#                                   'long': '-86.98310072',
#                                   'name': 'Limestone'},
#                                  {'confirmed': 524,
#                                   'confirmed_diff': 3,
#                                   'date': '2020-07-22',
#                                   'deaths': 24,
#                                   'deaths_diff': 0,
#                                   'fips': 1085,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.1597283',
#                                   'long': '-86.65158371',
#                                   'name': 'Lowndes'},
#                                  {'confirmed': 269,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 11,
#                                   'deaths_diff': 1,
#                                   'fips': 1087,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.38759944',
#                                   'long': '-85.69267724',
#                                   'name': 'Macon'},
#                                  {'confirmed': 3741,
#                                   'confirmed_diff': 83,
#                                   'date': '2020-07-22',
#                                   'deaths': 16,
#                                   'deaths_diff': 2,
#                                   'fips': 1089,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.76327133',
#                                   'long': '-86.55069633',
#                                   'name': 'Madison'},
#                                  {'confirmed': 438,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 11,
#                                   'deaths_diff': 0,
#                                   'fips': 1091,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.24767634',
#                                   'long': '-87.78796182',
#                                   'name': 'Marengo'},
#                                  {'confirmed': 441,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 21,
#                                   'deaths_diff': 4,
#                                   'fips': 1093,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.13697363',
#                                   'long': '-87.88704173',
#                                   'name': 'Marion'},
#                                  {'confirmed': 2461,
#                                   'confirmed_diff': 35,
#                                   'date': '2020-07-22',
#                                   'deaths': 21,
#                                   'deaths_diff': 1,
#                                   'fips': 1095,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.36975964',
#                                   'long': '-86.30486727',
#                                   'name': 'Marshall'},
#                                  {'confirmed': 6443,
#                                   'confirmed_diff': 164,
#                                   'date': '2020-07-22',
#                                   'deaths': 168,
#                                   'deaths_diff': 7,
#                                   'fips': 1097,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '30.78472347',
#                                   'long': '-88.20842409',
#                                   'name': 'Mobile'},
#                                  {'confirmed': 332,
#                                   'confirmed_diff': 9,
#                                   'date': '2020-07-22',
#                                   'deaths': 3,
#                                   'deaths_diff': 0,
#                                   'fips': 1099,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.56729412',
#                                   'long': '-87.36995001',
#                                   'name': 'Monroe'},
#                                  {'confirmed': 5329,
#                                   'confirmed_diff': 85,
#                                   'date': '2020-07-22',
#                                   'deaths': 127,
#                                   'deaths_diff': 2,
#                                   'fips': 1101,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.2206831',
#                                   'long': '-86.20969272',
#                                   'name': 'Montgomery'},
#                                  {'confirmed': 1784,
#                                   'confirmed_diff': 40,
#                                   'date': '2020-07-22',
#                                   'deaths': 11,
#                                   'deaths_diff': 1,
#                                   'fips': 1103,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.45500589',
#                                   'long': '-86.85475946',
#                                   'name': 'Morgan'},
#                                  {'confirmed': 0,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 80001,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': None,
#                                   'long': None,
#                                   'name': 'Out of AL'},
#                                  {'confirmed': 351,
#                                   'confirmed_diff': 12,
#                                   'date': '2020-07-22',
#                                   'deaths': 3,
#                                   'deaths_diff': 0,
#                                   'fips': 1105,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.64048341',
#                                   'long': '-87.29770589',
#                                   'name': 'Perry'},
#                                  {'confirmed': 312,
#                                   'confirmed_diff': 2,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 2,
#                                   'fips': 1107,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.28094866',
#                                   'long': '-88.08818103',
#                                   'name': 'Pickens'},
#                                  {'confirmed': 562,
#                                   'confirmed_diff': 10,
#                                   'date': '2020-07-22',
#                                   'deaths': 6,
#                                   'deaths_diff': 0,
#                                   'fips': 1109,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.80396383',
#                                   'long': '-85.9408295',
#                                   'name': 'Pike'},
#                                  {'confirmed': 338,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 10,
#                                   'deaths_diff': 0,
#                                   'fips': 1111,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.29526734',
#                                   'long': '-85.45708831',
#                                   'name': 'Randolph'},
#                                  {'confirmed': 965,
#                                   'confirmed_diff': 15,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 1,
#                                   'fips': 1113,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.28725256',
#                                   'long': '-85.18415324',
#                                   'name': 'Russell'},
#                                  {'confirmed': 2398,
#                                   'confirmed_diff': 59,
#                                   'date': '2020-07-22',
#                                   'deaths': 27,
#                                   'deaths_diff': 0,
#                                   'fips': 1117,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.26879845',
#                                   'long': '-86.66232561',
#                                   'name': 'Shelby'},
#                                  {'confirmed': 885,
#                                   'confirmed_diff': 28,
#                                   'date': '2020-07-22',
#                                   'deaths': 5,
#                                   'deaths_diff': 1,
#                                   'fips': 1115,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.71902176',
#                                   'long': '-86.31029372',
#                                   'name': 'St. Clair'},
#                                  {'confirmed': 325,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 13,
#                                   'deaths_diff': 0,
#                                   'fips': 1119,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.59117397',
#                                   'long': '-88.19916205',
#                                   'name': 'Sumter'},
#                                  {'confirmed': 629,
#                                   'confirmed_diff': 13,
#                                   'date': '2020-07-22',
#                                   'deaths': 8,
#                                   'deaths_diff': 0,
#                                   'fips': 1121,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.37823223',
#                                   'long': '-86.16886178',
#                                   'name': 'Talladega'},
#                                  {'confirmed': 724,
#                                   'confirmed_diff': 7,
#                                   'date': '2020-07-22',
#                                   'deaths': 74,
#                                   'deaths_diff': 2,
#                                   'fips': 1123,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '32.86698258',
#                                   'long': '-85.79833053',
#                                   'name': 'Tallapoosa'},
#                                  {'confirmed': 3282,
#                                   'confirmed_diff': 34,
#                                   'date': '2020-07-22',
#                                   'deaths': 57,
#                                   'deaths_diff': 2,
#                                   'fips': 1125,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.28726072',
#                                   'long': '-87.52556818',
#                                   'name': 'Tuscaloosa'},
#                                  {'confirmed': 1400,
#                                   'confirmed_diff': 117,
#                                   'date': '2020-07-22',
#                                   'deaths': 39,
#                                   'deaths_diff': 4,
#                                   'fips': 90001,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': None,
#                                   'long': None,
#                                   'name': 'Unassigned'},
#                                  {'confirmed': 1271,
#                                   'confirmed_diff': 13,
#                                   'date': '2020-07-22',
#                                   'deaths': 53,
#                                   'deaths_diff': 3,
#                                   'fips': 1127,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '33.80270512',
#                                   'long': '-87.30027177',
#                                   'name': 'Walker'},
#                                  {'confirmed': 234,
#                                   'confirmed_diff': 9,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 0,
#                                   'fips': 1129,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.4092794',
#                                   'long': '-88.20689944',
#                                   'name': 'Washington'},
#                                  {'confirmed': 363,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 0,
#                                   'fips': 1131,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '31.98773215',
#                                   'long': '-87.30891118',
#                                   'name': 'Wilcox'},
#                                  {'confirmed': 358,
#                                   'confirmed_diff': 6,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 1,
#                                   'fips': 1133,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '34.15030532',
#                                   'long': '-87.37325922',
#                                   'name': 'Winston'}],
#                       'iso': 'USA',
#                       'lat': '32.3182',
#                       'long': '-86.9023',
#                       'name': 'US',
#                       'province': 'Alabama'}},
#           {'active': 2112,
#            'active_diff': 88,
#            'confirmed': 2131,
#            'confirmed_diff': 89,
#            'date': '2020-07-22',
#            'deaths': 19,
#            'deaths_diff': 1,
#            'fatality_rate': 0.0089,
#            'last_update': '2020-07-23 05:15:04',
#            'recovered': 0,
#            'recovered_diff': 0,
#            'region': {'cities': [{'confirmed': 1,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2013,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '55.32222414',
#                                   'long': '-161.9722021',
#                                   'name': 'Aleutians East'},
#                                  {'confirmed': 1,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2016,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '52.3233',
#                                   'long': '-174.1596',
#                                   'name': 'Aleutians West'},
#                                  {'confirmed': 1068,
#                                   'confirmed_diff': 41,
#                                   'date': '2020-07-22',
#                                   'deaths': 9,
#                                   'deaths_diff': 0,
#                                   'fips': 2020,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '61.14998174',
#                                   'long': '-149.14269860000005',
#                                   'name': 'Anchorage'},
#                                  {'confirmed': 17,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2050,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '60.90980451',
#                                   'long': '-159.8561831',
#                                   'name': 'Bethel'},
#                                  {'confirmed': 6,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2060,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '58.74513976',
#                                   'long': '-156.701064',
#                                   'name': 'Bristol Bay'},
#                                  {'confirmed': 1,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2068,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '63.67264044',
#                                   'long': '-150.0076108',
#                                   'name': 'Denali'},
#                                  {'confirmed': 331,
#                                   'confirmed_diff': 10,
#                                   'date': '2020-07-22',
#                                   'deaths': 3,
#                                   'deaths_diff': 1,
#                                   'fips': 2090,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '64.80726247',
#                                   'long': '-146.5692662',
#                                   'name': 'Fairbanks North Star'},
#                                  {'confirmed': 3,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2100,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '59.09893571',
#                                   'long': '-135.4679843',
#                                   'name': 'Haines'},
#                                  {'confirmed': 71,
#                                   'confirmed_diff': 7,
#                                   'date': '2020-07-22',
#                                   'deaths': 2,
#                                   'deaths_diff': 0,
#                                   'fips': 2110,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '58.45031811',
#                                   'long': '-134.200436',
#                                   'name': 'Juneau'},
#                                  {'confirmed': 255,
#                                   'confirmed_diff': 3,
#                                   'date': '2020-07-22',
#                                   'deaths': 2,
#                                   'deaths_diff': 0,
#                                   'fips': 2122,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '60.24429722',
#                                   'long': '-151.53888840000005',
#                                   'name': 'Kenai Peninsula'},
#                                  {'confirmed': 28,
#                                   'confirmed_diff': 3,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2130,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '55.57445008',
#                                   'long': '-130.975561',
#                                   'name': 'Ketchikan Gateway'},
#                                  {'confirmed': 5,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2150,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '57.65529415',
#                                   'long': '-153.7493579',
#                                   'name': 'Kodiak Island'},
#                                  {'confirmed': 3,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2158,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '62.15429159999999',
#                                   'long': '-163.39678830000003',
#                                   'name': 'Kusilvak'},
#                                  {'confirmed': 205,
#                                   'confirmed_diff': 8,
#                                   'date': '2020-07-22',
#                                   'deaths': 2,
#                                   'deaths_diff': 0,
#                                   'fips': 2170,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '62.31305045',
#                                   'long': '-149.5741743',
#                                   'name': 'Matanuska-Susitna'},
#                                  {'confirmed': 16,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2180,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '64.90320724',
#                                   'long': '-164.0353804',
#                                   'name': 'Nome'},
#                                  {'confirmed': 8,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 2185,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '69.31479216',
#                                   'long': '-153.4836093',
#                                   'name': 'North Slope'},
#                                  {'confirmed': 9,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
# ...
#                                   'deaths_diff': 0,
#                                   'fips': 55135,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.47068056',
#                                   'long': '-88.96534501',
#                                   'name': 'Waupaca'},
#                                  {'confirmed': 57,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 55137,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.11324419',
#                                   'long': '-89.24317107',
#                                   'name': 'Waushara'},
#                                  {'confirmed': 884,
#                                   'confirmed_diff': 8,
#                                   'date': '2020-07-22',
#                                   'deaths': 15,
#                                   'deaths_diff': 1,
#                                   'fips': 55139,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.06886922',
#                                   'long': '-88.64477096',
#                                   'name': 'Winnebago'},
#                                  {'confirmed': 140,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 0,
#                                   'fips': 55141,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.45537896',
#                                   'long': '-90.04158336',
#                                   'name': 'Wood'}],
#                       'iso': 'USA',
#                       'lat': '44.2685',
#                       'long': '-89.6165',
#                       'name': 'US',
#                       'province': 'Wisconsin'}},
#           {'active': 2263,
#            'active_diff': 50,
#            'confirmed': 2288,
#            'confirmed_diff': 50,
#            'date': '2020-07-22',
#            'deaths': 25,
#            'deaths_diff': 0,
#            'fatality_rate': 0.0109,
#            'last_update': '2020-07-23 05:15:04',
#            'recovered': 0,
#            'recovered_diff': 0,
#            'region': {'cities': [{'confirmed': 75,
#                                   'confirmed_diff': 2,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56001,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '41.65498705',
#                                   'long': '-105.7235415',
#                                   'name': 'Albany'},
#                                  {'confirmed': 33,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56003,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.52405055',
#                                   'long': '-107.9960365',
#                                   'name': 'Big Horn'},
#                                  {'confirmed': 96,
#                                   'confirmed_diff': -1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56005,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.24886082',
#                                   'long': '-105.5474404',
#                                   'name': 'Campbell'},
#                                  {'confirmed': 49,
#                                   'confirmed_diff': 7,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56007,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '41.69357844',
#                                   'long': '-106.9326084',
#                                   'name': 'Carbon'},
#                                  {'confirmed': 30,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56009,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '42.97272268',
#                                   'long': '-105.5081848',
#                                   'name': 'Converse'},
#                                  {'confirmed': 9,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56011,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.58855102',
#                                   'long': '-104.5697705',
#                                   'name': 'Crook'},
#                                  {'confirmed': 438,
#                                   'confirmed_diff': 7,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56013,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '43.04183996',
#                                   'long': '-108.6296893',
#                                   'name': 'Fremont'},
#                                  {'confirmed': 11,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56015,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '42.08798185',
#                                   'long': '-104.3534743',
#                                   'name': 'Goshen'},
#                                  {'confirmed': 14,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56017,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '43.71930657',
#                                   'long': '-108.4423174',
#                                   'name': 'Hot Springs'},
#                                  {'confirmed': 22,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 1,
#                                   'deaths_diff': 0,
#                                   'fips': 56019,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.04057166',
#                                   'long': '-106.5845174',
#                                   'name': 'Johnson'},
#                                  {'confirmed': 392,
#                                   'confirmed_diff': 4,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56021,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '41.30702520000001',
#                                   'long': '-104.6887497',
#                                   'name': 'Laramie'},
#                                  {'confirmed': 70,
#                                   'confirmed_diff': 6,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56023,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '42.26376367',
#                                   'long': '-110.6563997',
#                                   'name': 'Lincoln'},
#                                  {'confirmed': 182,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56025,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '42.96180148',
#                                   'long': '-106.797885',
#                                   'name': 'Natrona'},
#                                  {'confirmed': 2,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56027,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '43.05607708',
#                                   'long': '-104.4758896',
#                                   'name': 'Niobrara'},
#                                  {'confirmed': 94,
#                                   'confirmed_diff': 5,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56029,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.52157546',
#                                   'long': '-109.5852825',
#                                   'name': 'Park'},
#                                  {'confirmed': 5,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56031,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '42.13299116',
#                                   'long': '-104.966331',
#                                   'name': 'Platte'},
#                                  {'confirmed': 40,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56033,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '44.79048913',
#                                   'long': '-106.8862389',
#                                   'name': 'Sheridan'},
#                                  {'confirmed': 18,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56035,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '42.76558279',
#                                   'long': '-109.9130922',
#                                   'name': 'Sublette'},
#                                  {'confirmed': 201,
#                                   'confirmed_diff': 7,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56037,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '41.65943896',
#                                   'long': '-108.8827882',
#                                   'name': 'Sweetwater'},
#                                  {'confirmed': 234,
#                                   'confirmed_diff': 8,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56039,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '43.93522482',
#                                   'long': '-110.5890801',
#                                   'name': 'Teton'},
#                                  {'confirmed': 224,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56041,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '41.2878183',
#                                   'long': '-110.54757820000002',
#                                   'name': 'Uinta'},
#                                  {'confirmed': 0,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 24,
#                                   'deaths_diff': 0,
#                                   'fips': 90056,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': None,
#                                   'long': None,
#                                   'name': 'Unassigned'},
#                                  {'confirmed': 45,
#                                   'confirmed_diff': 1,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56043,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '43.90451606',
#                                   'long': '-107.68018700000002',
#                                   'name': 'Washakie'},
#                                  {'confirmed': 4,
#                                   'confirmed_diff': 0,
#                                   'date': '2020-07-22',
#                                   'deaths': 0,
#                                   'deaths_diff': 0,
#                                   'fips': 56045,
#                                   'last_update': '2020-07-23 05:15:04',
#                                   'lat': '43.83961191',
#                                   'long': '-104.5674881',
#                                   'name': 'Weston'}],
#                       'iso': 'USA',
#                       'lat': '42.7560',
#                       'long': '-107.3025',
#                       'name': 'US',
#                       'province': 'Wyoming'}}]}

# %%
#Loop through all dates established above
for date in dates:
    
    #Set up the params for USA and the current date, and request
    query_params = {'date' : date,
                    'iso' : 'USA'}
    response = requests.get(url, params=query_params)
    print(f"Retreiving {response.url}...")
    json = response.json()
    
    try:
        data = json['data']

        #In this API, the 'data' element is a list whose elements represent states
        #Loop through the list to extract by-state information
        for datum in data:
            
            try:
                
                #Get the state name from the current 'datum'
                region = datum['region']
                state = region['province']
                
                #Only proceed with reading if the state is an actual US state
                #Other information is not joinable to income and population data
                #and should be ignored for this project
                if (state in [states.name for states in us.states.STATES]):
                
                    #print(f"Loading information for {state}...")
                    
                    #Read fields for the current 'state' row
                    active = datum['active']
                    active_diff = datum['active_diff']
                    confirmed = datum['confirmed']
                    confirmed_diff = datum['confirmed_diff']
                    date = datum['date']
                    deaths = datum['deaths']
                    deaths_diff = datum['deaths_diff']
                    fatality_rate = datum['fatality_rate']
                    recovered = datum['recovered']
                    recovered_diff = datum['recovered_diff']
                    state_lat = region['lat']
                    state_lon = region['long']

                    #Create a dictionary with the contents for the current 'state' row
                    data_row = {
                        'Active' : active,
                        'Confirmed' : confirmed,
                        'Date' : date,
                        'Deaths' : deaths,
                        'Fatality Rate' : fatality_rate,
                        'Recovered' : recovered,
                        'State' : state,
                        'State Abbr' : us.states.lookup(state).abbr,
                        'Active Diff' : active_diff,
                        'Confirmed Diff' : confirmed_diff,
                        'Deaths Diff' : deaths_diff,
                        'Recovered Diff' : recovered_diff,
                        'Lat' : state_lat,
                        'Lon' : state_lon
                    }

                    #Append the dictionary as a row to the data frame
                    cases_df = cases_df.append(data_row, ignore_index=True)
                
            except KeyError: #If a particular data element doesn't have an expected field
                print("A requested field was not found; skipping...")
                
    except KeyError: #If a particular date result doesn't have an expected field
        print("No data returned; skipping...")

#Show a sample from the data frame to show it is populated
cases_df.head()
# Out:
# Retreiving https://covid-api.com/api/reports?date=2020-03-01&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-03-15&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-04-01&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-04-15&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-05-01&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-05-15&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-06-01&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-06-15&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-07-01&iso=USA...
# Retreiving https://covid-api.com/api/reports?date=2020-07-15&iso=USA...
#   Active Confirmed        Date Deaths Fatality Rate Recovered       State  \
# 0     12        12  2020-03-15      0             0         0     Alabama
# 1      1         1  2020-03-15      0             0         0      Alaska
# 2     12        13  2020-03-15      0             0         1     Arizona
# 3     16        16  2020-03-15      0             0         0    Arkansas
# 4    414       426  2020-03-15      6        0.0141         6  California
#
#   State Abbr Active Diff Confirmed Diff Deaths Diff Recovered Diff      Lat  \
# 0         AL           6              6           0              0  32.3182
# 1         AK           0              0           0              0  61.3707
# 2         AZ           1              1           0              0  33.7298
# 3         AR           4              4           0              0  34.9697
# 4         CA          85             86           1              0  36.1162
#
#          Lon
# 0   -86.9023
# 1  -152.4044
# 2  -111.4312
# 3   -92.3731
# 4  -119.6816

# %%
#Check that we have data in all rows of all columns
#This is particularly important for the measure columns (Cases, Deaths, etc.)
cases_df.count()
# Out:
# Active            450
# Confirmed         450
# Date              450
# Deaths            450
# Fatality Rate     450
# Recovered         450
# State             450
# State Abbr        450
# Active Diff       450
# Confirmed Diff    450
# Deaths Diff       450
# Recovered Diff    450
# Lat               450
# Lon               450
# dtype: int64

# %%
#Check to ensure there is no noise in the State Column
#Specifically, we should only have 50 unique values
print(len(cases_df['State'].unique()))
# Out:
# 50

# %%
#Save results to CSV for separate plotting (Uncomment the version of this line being run)
#cases_df.to_csv("Resources/CasesByState-Daily.csv", index=False)
cases_df.to_csv("Resources/CasesByState.csv", index=False)
